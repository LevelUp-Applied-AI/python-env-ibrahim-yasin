# %%
import pandas as pd

df = pd.read_csv("../sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#       name  score  passed
# 0  ibrahim     85    True
# 1     amer     72    True
# 2    hosam     60   False
# 3     ammr     91    True
# 4    hasan     45   False
#            score
# count   5.000000
# mean   70.600000
# std    18.662797
# min    45.000000
# 25%    60.000000
# 50%    72.000000
# 75%    85.000000
# max    91.000000
